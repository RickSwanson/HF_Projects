# %%
# !pip install torch torchvision torchaudio
import torch
print(torch.cuda.is_available())
# Out:
# 70005.84s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting touch
#   Downloading touch-2020.12.3.tar.gz (1.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torchvision in /usr/local/Caskroom/miniconda/base/lib/python3.12/site-packages (0.17.2)
# Requirement already satisfied: torchaudio in /usr/local/Caskroom/miniconda/base/lib/python3.12/site-packages (2.2.2)
# INFO: pip is looking at multiple versions of touch to determine which version is compatible with other requirements. This could take a while.
#   Downloading touch-2020.7.1.tar.gz (1.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Discarding https://files.pythonhosted.org/packages/21/5c/127da0d4218bef183e3c7d048b74c88c958d795636df666df2e12ecb80b0/touch-2020.7.1.tar.gz (from https://pypi.org/simple/touch/): Requested touch from https://files.pythonhosted.org/packages/21/5c/127da0d4218bef183e3c7d048b74c88c958d795636df666df2e12ecb80b0/touch-2020.7.1.tar.gz has inconsistent version: expected '2020.7.1', but metadata has '0.0.0'
#   Downloading touch-2019.4.13.tar.gz (1.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting public (from touch)
#   Downloading public-2020.12.3.tar.gz (2.1 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/Caskroom/miniconda/base/lib/python3.12/site-packages (from touch) (82.0.0)
# Collecting touch
#   Downloading touch-2019.3.24-py2.py3-none-any.whl.metadata (1.4 kB)
#   Downloading touch-2018.11.20-py2.py3-none-any.whl.metadata (1.3 kB)
#   Downloading touch-1.0.2.tar.gz (1.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fullpath (from touch)
#   Downloading fullpath-0.0.post0.tar.gz (683 bytes)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
#       running egg_info
#       writing fullpath.egg-info/PKG-INFO
#       writing dependency_links to fullpath.egg-info/dependency_links.txt
#       writing top-level names to fullpath.egg-info/top_level.txt
#       reading manifest file 'fullpath.egg-info/SOURCES.txt'
#       writing manifest file 'fullpath.egg-info/SOURCES.txt'
#       Traceback (most recent call last):
#         File "/usr/local/Caskroom/miniconda/base/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#         File "/usr/local/Caskroom/miniconda/base/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/usr/local/Caskroom/miniconda/base/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/ws/sgcq2fdd38jb4rrdq2j9fc3r0000gs/T/pip-build-env-ovv50udo/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/ws/sgcq2fdd38jb4rrdq2j9fc3r0000gs/T/pip-build-env-ovv50udo/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/ws/sgcq2fdd38jb4rrdq2j9fc3r0000gs/T/pip-build-env-ovv50udo/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/private/var/folders/ws/sgcq2fdd38jb4rrdq2j9fc3r0000gs/T/pip-build-env-ovv50udo/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 9, in <module>
#       RuntimeError: This is a dummy package that was never ment to be actually installed. Please contact platform(at)kiwi.com.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'fullpath' when getting requirements to build wheel
# False

# %%
use_cuda = torch.cuda.is_available()
if use_cuda:
    print('__CUDNN VERSION:', torch.backends.cudnn.version())
    print('__Number CUDA Devices:', torch.cuda.device_count())
    print('__CUDA Device Name:', torch.cuda.get_device_name(0))
    print('__CUDA Device Total Memory [GB]',
        torch.cuda.get_device_properties(0).total_memory/le9)

# %%
import GPUtil
GPUtio.getAvailable()

# %%
gpus=GPUtil.getGPUs()
for gpu i gpus:
    print("GPU ID:", gpu.id)
    print("GPU Name", gpu.name)
    print("GPU Utilization:", gpu.load * 100, "%")
    print("GPU Memory Utilization:", gpu.memoryUtio * 100, "%")
    print("GPU Temperature:", gpu.temperature, "C")
    print("GPU Total Memory:", gpu.memoryTotal, "MB")

# %%
from transformers import pipeline
question_classifier = pipeline("text-classification",
                             model="huaen/question_detection",
                             device = 0)
